# %% [markdown]
# # Music Information Retrieval

# %%
import IPython.display as ipd

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### What is MIR?
#
# Music information retrieval (MIR) is the interdisciplinary science of retrieving information from music.

# %% [markdown]
# Here is a sampling of tasks found in music information retrieval:
#
# - fingerprinting
# - cover song detection
# - genre recognition
# - transcription
# - recommendation
# - symbolic melodic similarity
# - mood
# - source separation
# - instrument recognition
# - pitch tracking
# - tempo estimation
# - score alignment
# - song structure/form
# - beat tracking
# - key detection
# - query by humming

# %% [markdown]
# ### Applications of MIR:
#
# - discover, organize, monetize media collections
# - search ("find me something that sounds like this") songs, loops, speech, environmental sounds, sound effects
# - workflows	in consumer products through machine hearing
# - automatic control of software and mobile devices

# %% [markdown]
# ### Commercial Applications:

# %% [markdown]
# Example: [Melodyne](http://www.celemony.com/en/start)

# %%
ipd.display(ipd.YouTubeVideo("-fTi7CxSnVk", start=10))

# %% [markdown]
# Example: [Auto-Tune](http://www.antarestech.com/)

# %%
ipd.display(ipd.YouTubeVideo("A0cfugW4DbE", start=150))

# %% [markdown]
# Example: Key Detection and Auto-harmonization with [iZotope Nectar 2](https://www.izotope.com/nectar2)

# %%
ipd.display(ipd.YouTubeVideo("TG-ivjyyYhM", start=35))

# %% [markdown]
# ## Dependencies and packages:

# %% [markdown]
# ### Audio Libraries

# %% [markdown]
# We will mainly use two libraries for audio acquisition and playback:

# %% [markdown]
# #### 1. librosa
#
#
# [`librosa`](https://librosa.github.io/librosa/index.html) is a Python package for music and audio processing by [Brian McFee](https://bmcfee.github.io/). A large portion was ported from [Dan Ellis's Matlab audio processing examples](http://www.ee.columbia.edu/%7Edpwe/resources/matlab/).

# %% [markdown]
# #### 2. IPython.display.Audio
#
# [`IPython.display.Audio`](http://ipython.org/ipython-doc/stable/api/generated/IPython.display.html#IPython.display.Audio) lets you play audio directly in an IPython notebook.

# %% [markdown]
# #### SoX
#
# [SoX](http://sox.sourceforge.net/) is a command-line utility for audio processing, e.g. convert file format, convert sample rate, remix, trim, pad, normalize, etc.

# %% [markdown]
# #### ffmpeg
#
# [ffmpeg](https://www.ffmpeg.org/) is a framework to convert among different audio and video file formats. Use `ffmpeg` if you want to convert WAV to MP3.

# %% [markdown]
# ## Audio Samples Used:

# %%
ls Audio
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is BC1A-FC61
#
#  Directory of d:\work\music-information-retrieval\music-information-retrieval\Audio
#
# 07/28/2023  02:54 PM    <DIR>          .
# 07/28/2023  02:54 PM    <DIR>          ..
# 03/19/2021  01:27 AM           102,816 clarinet-c6.wav
# 03/19/2021  01:27 AM            73,544 flute-C6.wav
# 03/19/2021  01:27 AM           262,342 guitar-c6.wav
# 03/19/2021  01:27 AM            47,294 oboe-c6.wav
# 03/19/2021  01:27 AM            22,044 piano-C6.wav
# 03/19/2021  01:27 AM            99,270 simple-loop.wav
# 03/19/2021  01:27 AM            44,144 test.wav
# 03/19/2021  01:27 AM            44,804 test2.wav
# 03/19/2021  01:27 AM           163,396 trumpet-C6.wav
# 03/19/2021  01:27 AM            73,544 violin-C6.wav
#               10 File(s)        933,198 bytes
#                2 Dir(s)  206,136,283,136 bytes free
